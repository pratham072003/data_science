# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:/Users/PRATHAM HASTIR/Downloads/Breast_Cancer.csv")

# %%
data
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_enc=LabelEncoder()

# %%
data['Race']=label_enc.fit_transform(data['Race'])
data['differentiate']=label_enc.fit_transform(data['differentiate'])
data['N Stage']=label_enc.fit_transform(data['N Stage'])
data['T Stage ']=label_enc.fit_transform(data['T Stage '])
data['A Stage']=label_enc.fit_transform(data['A Stage'])
data['Estrogen Status']=label_enc.fit_transform(data['Estrogen Status'])
data['Progesterone Status']=label_enc.fit_transform(data['Progesterone Status'])
data['Status']=label_enc.fit_transform(data['Status'])
data['6th Stage']=label_enc.fit_transform(data['6th Stage'])
data['Marital Status']=label_enc.fit_transform(data['Marital Status'])
data['Grade']=label_enc.fit_transform(data['Grade'])

# %%
data
# Out:
#       Age  Race  Marital Status  T Stage   N Stage  6th Stage  differentiate  \
# 0      68     2               1         0        0          0              1
# 1      50     2               1         1        1          2              0
# 2      58     2               0         2        2          4              0
# 3      58     2               1         0        0          0              1
# 4      47     2               1         1        0          1              1
# ...   ...   ...             ...       ...      ...        ...            ...
# 4019   62     1               1         0        0          0              0
# 4020   56     2               0         1        1          2              0
# 4021   68     2               1         1        0          1              0
# 4022   58     0               0         1        0          1              0
# 4023   46     2               1         1        0          1              0
#
# ...

# %%
label=data['Status']
data.drop('Status',axis=1,inplace=True)

# %%
data
# Out:
#       Age  Race  Marital Status  T Stage   N Stage  6th Stage  differentiate  \
# 0      68     2               1         0        0          0              1
# 1      50     2               1         1        1          2              0
# 2      58     2               0         2        2          4              0
# 3      58     2               1         0        0          0              1
# 4      47     2               1         1        0          1              1
# ...   ...   ...             ...       ...      ...        ...            ...
# 4019   62     1               1         0        0          0              0
# 4020   56     2               0         1        1          2              0
# 4021   68     2               1         1        0          1              0
# 4022   58     0               0         1        0          1              0
# 4023   46     2               1         1        0          1              0
#
# ...

# %%
label
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4019    0
# 4020    0
# 4021    0
# 4022    0
# 4023    0
# Name: Status, Length: 4024, dtype: int32

# %%
age=data['Age']
u1=np.mean(age,axis=0)
std1=np.std(age,axis=0)
age=(age-u1)/std1

Tumor_Size=data['Tumor Size']
u2=np.mean(Tumor_Size,axis=0)
std2=np.std(Tumor_Size,axis=0)
Tumor_Size=(Tumor_Size-u2)/std2

Regional_Node=data['Regional Node Examined']
u3=np.mean(Regional_Node,axis=0)
std3=np.std(Regional_Node,axis=0)
Regional_Node=(Regional_Node-u3)/std3

Survival=data['Survival Months']
u4=np.mean(Survival,axis=0)
std4=np.std(Survival,axis=0)
Survival=(Survival-u4)/std4

# %%
label=np.array(label)
data=np.array(data)

# %%
split=0.95
X_train=data[:int(split*data.shape[0])]
X_test=data[int(split*data.shape[0]):]
Y_train=label[:int(split*data.shape[0])]
Y_test=label[int(split*data.shape[0]):]

# %%
X_test.shape,Y_test.shape,X_train.shape,Y_train.shape
# Out:
# ((202, 15), (202,), (3822, 15), (3822,))

# %%
ones=np.ones((X_train.shape[0],1))
X_train=np.hstack((ones,X_train))

# %%
X_train.shape
# Out:
# (3822, 16)

# %%
def hypothesis(X,theta):
    return 1/(1+np.exp(-1*np.dot(X,theta)))

# %%
def loss_func(x,y,weights):
    h_x=hypothesis(x,weights)
    loss=np.mean(y*np.log(h_x)+(1-y)*np.log((1-h_x)))

    return -1*loss

# %%
def gradient(x,y,weight):
    y_pred=hypothesis(x,weight)
    grad=np.dot(x.T,(y-y_pred))
    
    return grad/x.shape[0]

# %%
def gradient_descent(x, y, learning_rate = 0.02):
    
    weight = np.zeros((x.shape[1], ))
    
    cost = []
    
    epoch = 5000
    
    for i in range(epoch):
        grad = gradient(x, y, weight)
        
        loss = loss_func(x, y, weight)
        cost.append(loss)
        weight= weight+learning_rate * grad
        
    return cost, weight

# %%
cost,theta=gradient_descent(X_train,Y_train)
# Out:
# C:\Users\PRATHAM HASTIR\AppData\Local\Temp\ipykernel_51036\2438206649.py:3: RuntimeWarning: divide by zero encountered in log
#   loss=np.mean(y*np.log(h_x)+(1-y)*np.log((1-h_x)))
# C:\Users\PRATHAM HASTIR\AppData\Local\Temp\ipykernel_51036\2438206649.py:3: RuntimeWarning: invalid value encountered in multiply
#   loss=np.mean(y*np.log(h_x)+(1-y)*np.log((1-h_x)))

# %%
plt.plot(cost)

# %%
X_train
# Out:
# array([[ 1., 68.,  2., ..., 24.,  1., 60.],
#        [ 1., 50.,  2., ..., 14.,  5., 62.],
#        [ 1., 58.,  2., ..., 14.,  7., 75.],
#        ...,
#        [ 1., 58.,  2., ..., 11.,  2., 95.],
#        [ 1., 63.,  2., ..., 22.,  1., 99.],
#        [ 1., 67.,  2., ...,  8.,  1., 93.]])

# %%
Y_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0])
